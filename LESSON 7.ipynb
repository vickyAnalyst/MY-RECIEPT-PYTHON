# %%
# ADDRESS AND DISCRIPTION
N1 = "WELCOME TO HOT BREAD CAFE"
N2 = "AJAH BADORE"
N3 = "LAGOS STATE"
N4 = "="*30
N5 = "Qty  Description"   "           "  "Extend"
N6 = "-"*30


# PRODUCT NAME AND PRICE
p1_name, p1_price = "1coconut rice",  2186.00
p2_name, p2_price = "1chicken",       377.00
p3_name, p3_price = "1bottlewater",   1125.00
p4_name, p4_price = "1friedplantain", 400.00
p5_name, p5_price = "2chapman",       650.00
p6_name, p6_price= "2takeaway plate", 4500.00

#CAlCULATE THE TOTAL AND SUBTOTAL
TOTAL = p1_price + p2_price + p3_price + p4_price + p5_price + p6_price 
SUB_TOTAL = p1_price + p2_price + p3_price + p4_price + p5_price + p6_price 
PAIDCASH =  p1_price + p2_price + p3_price + p4_price + p5_price + p6_price 

# DATE, TIME AND APPRECIATION MESSAGE
RECEIPT = "1567"
Product = "8"
Date   =  "2/3/2023" 
Time = "9:20 pm"
Cashier  = "KAREN"
Message = "Thank you for your patronage"
Visit   = "visit us again for that awesome taste"


A = ("RECEIPT#:  ")
B = ("Product:  ")
C = ("Date:  " ) 
D = ("Time:  ")
E = ("Cashier:  ")

print(N1)
print(N2)
print(N3)
print(N4)
print(N5)
print(N6)

print(p1_name +"                "+str(p1_price)) 
print(p2_name+ "                     "+str(p2_price))  
print(p3_name+ "                 "+str(p3_price))
print(p4_name+ "               "+str(p4_price))
print(p5_name+ "                     "+str(p5_price))
print(p6_name+"              "+str(p6_price))

print("-"*21)
print(f"SUB_TOTAL      {SUB_TOTAL:.2f}")
print(f"TOTAL          #{TOTAL:.2f}")
print(f"PAIDCASH       #{PAIDCASH:.2f}")

print("*"*21)

print(A, RECEIPT)
print(B, Product)
print(C, Date)
print(D, Time)
print(E, Cashier)
print(Message)
print(Visit)
# Out:
# WELCOME TO HOT BREAD CAFE
# AJAH BADORE
# LAGOS STATE
# ...
# Qty  Description           Extend
# ------------------------------
# 1coconut rice                2186.0
# 1chicken                     377.0
# 1bottlewater                 1125.0
# 1friedplantain               400.0
# 2chapman                     650.0
# 2takeaway plate              4500.0
# ---------------------
# SUB_TOTAL      9238.00
# TOTAL          #9238.00
# PAIDCASH       #9238.00
# *********************
# RECEIPT#:   1567
# Product:   8
# Date:   2/3/2023
# Time:   9:20 pm
# Cashier:   KAREN
# Thank you for your patronage
# visit us again for that awesome taste
